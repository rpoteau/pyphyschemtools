# %% [markdown]
# $$
# \hat{G}^{[0]}(t)=\left\{ \begin{array}{ttt}
# G_{0}+\beta\dfrac{kt}{b_{\infty}}\left(G_{\infty}-G_{0}\right) &  & t\leq\dfrac{a_{0}}{\alpha k}=\dfrac{b_{\infty}}{\beta k}\\
# G_{\infty} &  & t>\dfrac{a_{0}}{\alpha k}=\dfrac{b_{\infty}}{\beta k}
# \end{array}\right.
# $$

# %%
def tfin(binf,beta,k):
    return binf/(beta*k)

binf = 2.0866e+00
beta = 1
k = 1.1260e-01

print(tfin(binf,beta,k))
# Out:
# 18.53108348134991

# %%
binf = 2.928
beta = 1
k = 2.28e-02

print(tfin(binf,beta,k))
# Out:
# 128.42105263157893
