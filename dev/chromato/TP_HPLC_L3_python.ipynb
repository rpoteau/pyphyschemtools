# %% [markdown]
# ## <center> TP n°1 HPLC</center>
# ### <center> jupyter notebook </center>
#
# ## II – Dosage externe du propylparabène
#
# **Gamme étalon :** <br>
# Après avoir réalisé les injections des solutions étalons et complété le tableau de la feuille réponse :

# %% [markdown]
# **1.** Créer un tableau `Conc` contenant les valeurs des concentrations de la gamme étalon et un tableau `Aire` contenant la moyenne des aires des signaux pour chaque concentration de la gamme étalon.

# %% [markdown]
# **2.** On souhaite trouver l'équation de la courbe d'étalonnage. Elle est de la forme $Y=aX+b$. Rechercher $a$ et $b$ par régression linéaire à l'aide de la fonction `linregress` du module `scipy.stats` (*cf* fiche TP_HPLC_L3_2025_linregress). Afficher l'équation de la droite.

# %% [markdown]
# **3.** Donner le coefficient de corrélation de la courbe d’étalonnage. Afficher le résultat

# %% [markdown]
# **3.** Créer un graphique comprenant :
# - vos points expérimentaux (utiliser des ronds bleus),
# - la droite de régression (en rouge) à partir des coefficients trouvés,
# - l'équation de la droite en légende.
# - Vous choisirez une taille 4*3 pour votre graphique.

# %% [markdown]
# **4.** Calculer la concentration du propylparabène dans l'échantillon. Afficher le résultat
