# %%
# This now triggers vID.init() automatically via __init__.py
import pyphyschemtools as t4pPC
from pyphyschemtools import fg, hl, bg, color

t4pPC.init('t4pPC')
# Out:
# <style>
# h1, h2, h3, h4, h5, h6 {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: bold;
# }
# body, intro, introE, introT, rq, rqE, rqT, ex, exE, app, appE, sol, todo, hint, hintE, figure  {
#   font-family: Verdana, "DejaVu Sans", "Bitstream Vera Sans", Geneva, sans-serif;
#   font-weight: 400;
#   font-size: 12px;
# }
# h1 {
#   border: 0 solid #333;
#   padding: 30px ;
#   color: white;
#   background: #b11d01;
#   text-align: center;
# }
# h2 {
#   border: 3px solid #333;
#   padding: 18px ;
#   color: #b11d01;
#   background: #ffffff;
#   text-align: center;
# }
# h3 {
#   border: 0 solid #333;
#   padding: 12px ;
#   color: #000000;
#   background: #c1c1c1;
#   text-align: left;
# }
# h4 {
#   border: 0 solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #d9fffc;
#   text-align: left;
# }
# h5 {
#   border: 1px solid #333;
#   padding: 2px ;
#   color: #000000;
#   background: #ffffff;
#   text-align: left;
# ...

# %%
from IPython.display import HTML
import requests

# On récupère le CSS directement depuis votre GitHub pour être sûr qu'il est à jour
css_url = "https://github.com/rpoteau/pyphyschemtools/blob/main/pyphyschemtools/resources/css/visualID.css"
css_content = requests.get(css_url).text

display(HTML(f"<style>{css_content}</style>"))
